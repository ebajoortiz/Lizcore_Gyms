# %%
import pandas as pd

# %%
df = pd.read_csv('../data/lizcore_gym_data.csv')

# %%
df.sample(5)
# Out:
#            date  user_id  route_id grade  attempts  success  \
# 354  2025-02-24       92        11    5c       4.0        1
# 155  2025-02-06       93         4    6b       5.0        1
# 340  2025-01-26       60         4    7b       4.0        0
# 132  2025-02-20       33        23    6c       5.0        1
# 251  2025-02-18        5        21    7b       4.0        1
#
#      session_duration_min
# 354             96.535978
# 155             92.294212
# 340            111.306953
# 132             89.012462
# 251            105.236076

# %%
print(f'nuestro conjunto de datos presenta {df.shape[0]} filas y {df.shape[1]} columnas')
# Out:
# nuestro conjunto de datos presenta 500 filas y 7 columnas
